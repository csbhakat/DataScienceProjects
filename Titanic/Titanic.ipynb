# %%
import numpy as np
import pandas as pd
import os

# %%
raw_data_path = os.path.join(os.path.pardir,'data','raw')
train_file_path = os.path.join('C:\Users\chbhakat\Desktop\DS\Kaggle\Titanic\data\\raw\\train.csv')
test_file_path = os.path.join('C:\Users\chbhakat\Desktop\DS\Kaggle\Titanic\data\\raw\\test.csv')

# %%
train_df = pd.read_csv(train_file_path,index_col='PassengerId')
test_df = pd.read_csv(test_file_path,index_col='PassengerId')

# %%
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 24 columns):
# Survived            890 non-null float64
# Sex                 890 non-null object
# IsMother            890 non-null float64
# IsMale              891 non-null int64
# Deck_A              891 non-null int64
# Deck_B              891 non-null int64
# Deck_C              891 non-null int64
# Deck_D              891 non-null int64
# Deck_E              891 non-null int64
# Deck_F              891 non-null int64
# Deck_G              891 non-null int64
# Deck_Z              891 non-null int64
# Pclass_1.0          891 non-null int64
# Pclass_2.0          891 non-null int64
# Pclass_3.0          891 non-null int64
# Embarked_C          891 non-null int64
# Embarked_Q          891 non-null int64
# Embarked_S          891 non-null int64
# FareBin_VeyLow      891 non-null int64
# FareBin_Low         891 non-null int64
# FareBin_High        891 non-null int64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 23 columns):
# Sex                 418 non-null object
# IsMother            418 non-null float64
# IsMale              418 non-null int64
# Deck_A              418 non-null int64
# Deck_B              418 non-null int64
# Deck_C              418 non-null int64
# Deck_D              418 non-null int64
# Deck_E              418 non-null int64
# Deck_F              418 non-null int64
# Deck_G              418 non-null int64
# Deck_Z              418 non-null int64
# Pclass_1.0          418 non-null int64
# Pclass_2.0          418 non-null int64
# Pclass_3.0          418 non-null int64
# Embarked_C          418 non-null int64
# Embarked_Q          418 non-null int64
# Embarked_S          418 non-null int64
# FareBin_VeyLow      418 non-null int64
# FareBin_Low         418 non-null int64
# FareBin_High        418 non-null int64
# FareBin_VeryHigh    418 non-null int64
# ...

# %%
test_df['Survived']=-888

# %%
df=pd.concat((train_df,test_df),axis=0)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 24 columns):
# AgeState_Adult      1309 non-null int64
# AgeState_Child      1309 non-null int64
# Deck_A              1309 non-null int64
# Deck_B              1309 non-null int64
# Deck_C              1309 non-null int64
# Deck_D              1309 non-null int64
# Deck_E              1309 non-null int64
# Deck_F              1309 non-null int64
# Deck_G              1309 non-null int64
# Deck_Z              1309 non-null int64
# Embarked_C          1309 non-null int64
# Embarked_Q          1309 non-null int64
# Embarked_S          1309 non-null int64
# FareBin_High        1309 non-null int64
# FareBin_Low         1309 non-null int64
# FareBin_VeryHigh    1309 non-null int64
# FareBin_VeyLow      1309 non-null int64
# IsMale              1309 non-null int64
# IsMother            1308 non-null float64
# Pclass_1.0          1309 non-null int64
# Pclass_2.0          1309 non-null int64
# ...

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# ...

# %%
df[['Name','Survived']]
# Out:
#                                                           Name  Survived
# PassengerId
# 1                                      Braund, Mr. Owen Harris         0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 3                                       Heikkinen, Miss. Laina         1
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 5                                     Allen, Mr. William Henry         0
# 6                                             Moran, Mr. James         0
# 7                                      McCarthy, Mr. Timothy J         0
# 8                               Palsson, Master. Gosta Leonard         0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 10                         Nasser, Mrs. Nicholas (Adele Achem)         1
# 11                             Sandstrom, Miss. Marguerite Rut         1
# 12                                    Bonnell, Miss. Elizabeth         1
# ...

# %%
df.loc[5:10,]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
#
#                 Sex  SibSp  Survived  Ticket
# PassengerId
# ...

# %%
male_passenger=df.loc[df.Sex=='male',:]
len(male_passenger)
# Out:
# 843

# %%
len(df.Sex=='male')
# Out:
# 1309

# %%
df.Sex=='male'
# Out:
# PassengerId
# 1        True
# 2       False
# 3       False
# 4       False
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13       True
# 14       True
# 15      False
# 16      False
# 17       True
# 18       True
# 19      False
# 20      False
# 21       True
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27       True
# 28       True
# 29      False
# 30       True
#         ...
# 1280     True
# 1281     True
# 1282     True
# 1283    False
# 1284     True
# 1285     True
# 1286     True
# 1287    False
# 1288     True
# 1289    False
# 1290     True
# 1291     True
# 1292    False
# 1293     True
# 1294    False
# 1295     True
# 1296     True
# 1297     True
# 1298     True
# 1299     True
# 1300    False
# 1301    False
# 1302    False
# 1303    False
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# 1309     True
# ...

# %%
len(df.loc[((df.Sex=='male')&(df.Pclass==1)),:])
# Out:
# 179

# %%
df.describe()
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#           Survived
# count  1309.000000
# mean   -283.301757
# std     414.337413
# min    -888.000000
# 25%    -888.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.Fare.mean()
# Out:
# 33.2954792813456

# %%
df.Fare.plot(kind='box')

# %%
df.describe(include='all')
# Out:
#                 Age        Cabin Embarked         Fare                  Name  \
# count   1046.000000          295     1307  1308.000000                  1309
# unique          NaN          186        3          NaN                  1307
# top             NaN  C23 C25 C27        S          NaN  Connolly, Miss. Kate
# freq            NaN            6      914          NaN                     2
# mean      29.881138          NaN      NaN    33.295479                   NaN
# std       14.413493          NaN      NaN    51.758668                   NaN
# min        0.170000          NaN      NaN     0.000000                   NaN
# 25%       21.000000          NaN      NaN     7.895800                   NaN
# 50%       28.000000          NaN      NaN    14.454200                   NaN
# 75%       39.000000          NaN      NaN    31.275000                   NaN
# max       80.000000          NaN      NaN   512.329200                   NaN
#
# ...

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df[df.Survived!=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
df.plot.scatter(x='Age',y='Fare',color='c',title ='Age vs Fare')

# %%
df.head(100)
# Out:
#                Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.00          NaN        S    7.2500
# 2            38.00          C85        C   71.2833
# 3            26.00          NaN        S    7.9250
# 4            35.00         C123        S   53.1000
# 5            35.00          NaN        S    8.0500
# 6              NaN          NaN        Q    8.4583
# 7            54.00          E46        S   51.8625
# 8             2.00          NaN        S   21.0750
# 9            27.00          NaN        S   11.1333
# 10           14.00          NaN        C   30.0708
# 11            4.00           G6        S   16.7000
# 12           58.00         C103        S   26.5500
# 13           20.00          NaN        S    8.0500
# 14           39.00          NaN        S   31.2750
# 15           14.00          NaN        S    7.8542
# 16           55.00          NaN        S   16.0000
# 17            2.00          NaN        Q   29.1250
# ...

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df.groupby(['Pclass'])['Fare','Age'].median()
# Out:
#            Fare   Age
# Pclass
# 1       60.0000  39.0
# 2       15.0458  29.0
# 3        8.0500  24.0

# %%
df.groupby(['Pclass']).agg({'Fare':'mean','Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
df.Fare.value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
# 10.5000    35
# 7.7750     26
# 7.2292     24
# 7.9250     23
# 26.5500    22
# 8.6625     21
# 7.8542     21
# 7.2250     21
# 7.2500     18
# 0.0000     17
# 21.0000    14
# 9.5000     12
# 16.1000    12
# 14.5000    11
# 69.5500    11
# 27.7208    11
# 7.7958     10
# 14.4542    10
# 7.8792     10
# 15.5000    10
# 24.1500     9
# 15.2458     9
# 7.0500      9
# 56.4958     8
# 46.9000     8
#            ..
# 45.5000     1
# 8.4333      1
# 8.1583      1
# 8.0292      1
# 12.7375     1
# 31.6833     1
# 42.5000     1
# 34.0208     1
# 25.9250     1
# 12.6500     1
# 7.0458      1
# 49.5000     1
# 7.7208      1
# 32.3208     1
# 6.4500      1
# 8.3000      1
# 7.5208      1
# 28.7125     1
# 25.5875     1
# 7.7292      1
# 9.8458      1
# 8.6542      1
# 25.7000     1
# 10.1708     1
# 7.3125      1
# 33.5000     1
# 7.8000      1
# 26.3875     1
# 15.5792     1
# 7.1417      1
# ...

# %%
df.Age.value_counts()
# Out:
# 24.00    47
# 22.00    43
# 21.00    41
# 30.00    40
# 18.00    39
# 25.00    34
# 28.00    32
# 36.00    31
# 26.00    30
# 29.00    30
# 27.00    30
# 19.00    29
# 23.00    26
# 32.00    24
# 20.00    23
# 35.00    23
# 31.00    23
# 45.00    21
# 33.00    21
# 17.00    20
# 39.00    20
# 16.00    19
# 42.00    18
# 40.00    18
# 34.00    16
# 50.00    15
# 47.00    14
# 48.00    14
# 38.00    14
# 2.00     12
#          ..
# 28.50     3
# 12.00     3
# 0.83      3
# 34.50     2
# 71.00     2
# 45.50     2
# 70.00     2
# 14.50     2
# 30.50     2
# 0.92      2
# 36.50     2
# 23.50     1
# 67.00     1
# 60.50     1
# 38.50     1
# 0.17      1
# 55.50     1
# 0.33      1
# 20.50     1
# 24.50     1
# 66.00     1
# 0.42      1
# 70.50     1
# 11.50     1
# 26.50     1
# 76.00     1
# 22.50     1
# 74.00     1
# 80.00     1
# 0.67      1
# Name: Age, Length: 98, dtype: int64

# %%
df.head(1000)
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 2            38.0          C85        C   71.2833
# 3            26.0          NaN        S    7.9250
# 4            35.0         C123        S   53.1000
# 5            35.0          NaN        S    8.0500
# 6             NaN          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 9            27.0          NaN        S   11.1333
# 10           14.0          NaN        C   30.0708
# 11            4.0           G6        S   16.7000
# 12           58.0         C103        S   26.5500
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 15           14.0          NaN        S    7.8542
# 16           55.0          NaN        S   16.0000
# 17            2.0          NaN        Q   29.1250
# ...

# %%
df[df.Embarked.isnull()]
# Out:
#               Age Cabin Embarked  Fare  \
# PassengerId
# 62           38.0   B28      NaN  80.0
# 830          62.0   B28      NaN  80.0
#
#                                                   Name  Parch  Pclass     Sex  \
# PassengerId
# 62                                 Icard, Miss. Amelie      0       1  female
# 830          Stone, Mrs. George Nelson (Martha Evelyn)      0       1  female
#
#              SibSp  Survived  Ticket
# PassengerId
# 62               0         1  113572
# 830              0         1  113572

# %%
pclass=df[df.Pclass==1]
pclass.Embarked.value_counts()
# Out:
# S    177
# C    141
# Q      3
# Name: Embarked, dtype: int64

# %%
df[df.Pclass==1].Embarked.value_counts()
# Out:
# S    177
# C    141
# Q      3
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
df.Embarked.fillna('C',inplace=True)

# %%
df[df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Fare.isnull()]
# Out:
#               Age Cabin Embarked  Fare                Name  Parch  Pclass  \
# PassengerId
# 1044         60.5   NaN        S   NaN  Storey, Mr. Thomas      0       3
#
#               Sex  SibSp  Survived Ticket
# PassengerId
# 1044         male      0      -888   3701

# %%
df[df.Pclass==3].Fare.median()
# Out:
# 8.05

# %%
df[df.Pclass==2].Fare.median()
# Out:
# 15.0458

# %%
df[df.Pclass==1].Fare.median()
# Out:
# 60.0

# %%
df.groupby(['Pclass']).Fare.median()
# Out:
# Pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: Fare, dtype: float64

# %%
pd.crosstab(df[df.Pclass==3].Pclass,df[df.Pclass==3].Fare)
# Out:
# Fare    0.0000   3.1708   4.0125   6.2375   6.4375   6.4500   6.4958   \
# Pclass
# 3             4        1        1        1        3        1        3
#
# Fare    6.7500   6.8583   6.9500   ...  25.4667  27.9000  29.1250  31.2750  \
# Pclass                             ...
# 3             2        1        2  ...        5        6        6        7
#
# Fare    31.3875  34.3750  39.6875  46.9000  56.4958  69.5500
# Pclass
# 3             7        5        7        8        8       11
#
# [1 rows x 133 columns]

# %%
df.Fare.fillna('8.05',inplace=True)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null object
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 162.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null object
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 162.7+ KB

# %%
df[df.Age.isnull()]
# Out:
#              Age  Cabin Embarked     Fare  \
# PassengerId
# 6            NaN    NaN        Q   8.4583
# 18           NaN    NaN        S       13
# 20           NaN    NaN        C    7.225
# 27           NaN    NaN        C    7.225
# 29           NaN    NaN        Q   7.8792
# 30           NaN    NaN        S   7.8958
# 32           NaN    B78        C  146.521
# 33           NaN    NaN        Q     7.75
# 37           NaN    NaN        C   7.2292
# 43           NaN    NaN        C   7.8958
# 46           NaN    NaN        S     8.05
# 47           NaN    NaN        Q     15.5
# 48           NaN    NaN        Q     7.75
# 49           NaN    NaN        C  21.6792
# 56           NaN    C52        S     35.5
# 65           NaN    NaN        C  27.7208
# 66           NaN    NaN        C  15.2458
# 77           NaN    NaN        S   7.8958
# 78           NaN    NaN        S     8.05
# 83           NaN    NaN        Q   7.7875
# 88           NaN    NaN        S     8.05
# ...

# %%
df.Age.plot(kind='hist',bins=20,color='c')

# %%
df.Age.mean()
# Out:
# 29.881137667304014

# %%
df.groupby('Sex').Age.mean()
# Out:
# Sex
# female    28.687088
# male      30.585228
# Name: Age, dtype: float64

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df[df.Age.notnull()].boxplot('Age','Pclass')

# %%
pclass_age_median=df.groupby('Pclass').Age.transform('median')
df.Age.fillna(pclass_age_median, inplace=True)

# %%
pclass_age_median
# Out:
# PassengerId
# 1       24.0
# 2       39.0
# 3       24.0
# 4       39.0
# 5       24.0
# 6       24.0
# 7       39.0
# 8       24.0
# 9       24.0
# 10      29.0
# 11      24.0
# 12      39.0
# 13      24.0
# 14      24.0
# 15      24.0
# 16      29.0
# 17      24.0
# 18      29.0
# 19      24.0
# 20      24.0
# 21      29.0
# 22      29.0
# 23      24.0
# 24      39.0
# 25      24.0
# 26      24.0
# 27      24.0
# 28      39.0
# 29      24.0
# 30      24.0
#         ...
# 1280    24.0
# 1281    24.0
# 1282    39.0
# 1283    39.0
# 1284    24.0
# 1285    29.0
# 1286    24.0
# 1287    39.0
# 1288    24.0
# 1289    39.0
# 1290    24.0
# 1291    24.0
# 1292    39.0
# 1293    29.0
# 1294    39.0
# 1295    39.0
# 1296    39.0
# 1297    29.0
# 1298    29.0
# 1299    39.0
# 1300    24.0
# 1301    24.0
# 1302    24.0
# 1303    39.0
# 1304    24.0
# 1305    24.0
# 1306    39.0
# 1307    24.0
# 1308    24.0
# 1309    24.0
# Name: Age, Length: 1309, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null object
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 162.7+ KB

# %%
df.Age.plot(kind='hist',bins=20,color='c')

# %%
df.loc[df.Age>70]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q     7.75
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S       30
# 852          74.0   NaN        S    7.775
# 988          76.0   C46        S    78.85
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
#
#                 Sex  SibSp  Survived    Ticket
# PassengerId
# ...

# %%
Fare1=df.Fare.astype('float')
Fare1.plot(kind='hist',title='Histogram for Fare', bins=20,color='c');

# %%
Fare1.plot(kind='box')

# %%
df.loc[Fare1==Fare1.max()]
# Out:
#               Age        Cabin Embarked     Fare  \
# PassengerId
# 259          35.0          NaN        C  512.329
# 680          36.0  B51 B53 B55        C  512.329
# 738          35.0         B101        C  512.329
# 1235         58.0  B51 B53 B55        C  512.329
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
#
#                 Sex  SibSp  Survived    Ticket
# PassengerId
# 259          female      0         1  PC 17755
# 680            male      0         1  PC 17755
# 738            male      0         1  PC 17755
# 1235         female      0      -888  PC 17755

# %%
LogFare=np.log(Fare1+1.0)

# %%
Fare1.plot(kind='hist',bins=20,color='c')

# %%
pd.qcut(Fare1,4)
# Out:
# PassengerId
# 1         (-0.001, 7.896]
# 2       (31.275, 512.329]
# 3         (7.896, 14.454]
# 4       (31.275, 512.329]
# 5         (7.896, 14.454]
# 6         (7.896, 14.454]
# 7       (31.275, 512.329]
# 8        (14.454, 31.275]
# 9         (7.896, 14.454]
# 10       (14.454, 31.275]
# 11       (14.454, 31.275]
# 12       (14.454, 31.275]
# 13        (7.896, 14.454]
# 14       (14.454, 31.275]
# 15        (-0.001, 7.896]
# 16       (14.454, 31.275]
# 17       (14.454, 31.275]
# 18        (7.896, 14.454]
# 19       (14.454, 31.275]
# 20        (-0.001, 7.896]
# 21       (14.454, 31.275]
# 22        (7.896, 14.454]
# 23        (7.896, 14.454]
# 24      (31.275, 512.329]
# 25       (14.454, 31.275]
# 26      (31.275, 512.329]
# 27        (-0.001, 7.896]
# 28      (31.275, 512.329]
# 29        (-0.001, 7.896]
# 30        (-0.001, 7.896]
#               ...
# 1280      (-0.001, 7.896]
# 1281     (14.454, 31.275]
# 1282    (31.275, 512.329]
# 1283    (31.275, 512.329]
# ...

# %%
pd.qcut(Fare1,4,labels=["VeryLow","Low","High","VeryHigh"])
# Out:
# PassengerId
# 1        VeryLow
# 2       VeryHigh
# 3            Low
# 4       VeryHigh
# 5            Low
# 6            Low
# 7       VeryHigh
# 8           High
# 9            Low
# 10          High
# 11          High
# 12          High
# 13           Low
# 14          High
# 15       VeryLow
# 16          High
# 17          High
# 18           Low
# 19          High
# 20       VeryLow
# 21          High
# 22           Low
# 23           Low
# 24      VeryHigh
# 25          High
# 26      VeryHigh
# 27       VeryLow
# 28      VeryHigh
# 29       VeryLow
# 30       VeryLow
#           ...
# 1280     VeryLow
# 1281        High
# 1282    VeryHigh
# 1283    VeryHigh
# 1284        High
# 1285         Low
# 1286        High
# 1287    VeryHigh
# 1288     VeryLow
# 1289    VeryHigh
# 1290     VeryLow
# 1291     VeryLow
# 1292    VeryHigh
# 1293        High
# 1294    VeryHigh
# 1295    VeryHigh
# 1296        High
# 1297         Low
# 1298         Low
# 1299    VeryHigh
# 1300     VeryLow
# ...

# %%
pd.qcut(Fare1,4,labels=['VeyLow','Low','High','VeryHigh']).value_counts().plot(kind='hist',bins=20,color='c',rot=0)

# %%
df["FareBin"]=pd.qcut(Fare1,4,labels=['VeyLow','Low','High','VeryHigh'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null object
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# FareBin     1309 non-null category
# dtypes: category(1), float64(1), int64(4), object(6)
# memory usage: 164.2+ KB

# %%
pd.qcut(Fare1,4,labels=['VeyLow','Low','High','VeryHigh']).value_counts()
# Out:
# VeyLow      337
# High        328
# VeryHigh    323
# Low         321
# Name: Fare, dtype: int64

# %%
df.FareBin.value_counts()
# Out:
# VeyLow      337
# High        328
# VeryHigh    323
# Low         321
# Name: FareBin, dtype: int64

# %%
df["AgeState"]=np.where(df.Age>=18,'Adult','Child')

# %%
df["AgeState"].value_counts()
# Out:
# Adult    1155
# Child     154
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           497     52
# 1           281     61

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 13 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null object
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# FareBin     1309 non-null category
# AgeState    1309 non-null object
# dtypes: category(1), float64(1), int64(4), object(7)
# memory usage: 174.4+ KB

# %%
df["IsMother"]=np.where(((df.Sex=='female')&(df.Age>18)&(df.Parch>0)),1,0)

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.loc[df.Cabin=='T']=np.NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 14 columns):
# Age         1308 non-null float64
# Cabin       294 non-null object
# Embarked    1308 non-null object
# Fare        1308 non-null object
# Name        1308 non-null object
# Parch       1308 non-null float64
# Pclass      1308 non-null float64
# Sex         1308 non-null object
# SibSp       1308 non-null float64
# Survived    1308 non-null float64
# Ticket      1308 non-null object
# FareBin     1308 non-null category
# AgeState    1308 non-null object
# IsMother    1308 non-null float64
# dtypes: category(1), float64(6), object(7)
# memory usage: 184.6+ KB

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34',
#        'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37',
#        'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39',
#        'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41',
#        'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58',
# ...

# %%
def get_deck(Cabin):
    return np.where(pd.notnull(Cabin),str(Cabin)[0].upper(),'Z')
df['Deck']=df['Cabin'].map(lambda x:get_deck(x))

# %%
df.Deck.value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived , df[df.Survived!=-888].Deck)
# Out:
# Deck      A   B   C   D   E  F  G    Z
# Survived
# 0.0       8  12  24   8   8  5  2  481
# 1.0       7  35  35  25  24  8  2  206

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 15 columns):
# Age         1308 non-null float64
# Cabin       294 non-null object
# Embarked    1308 non-null object
# Fare        1308 non-null object
# Name        1308 non-null object
# Parch       1308 non-null float64
# Pclass      1308 non-null float64
# Sex         1308 non-null object
# SibSp       1308 non-null float64
# Survived    1308 non-null float64
# Ticket      1308 non-null object
# FareBin     1308 non-null category
# AgeState    1308 non-null object
# IsMother    1308 non-null float64
# Deck        1309 non-null object
# dtypes: category(1), float64(6), object(8)
# memory usage: 194.9+ KB

# %%
df["IsMale"]=np.where(df.Sex=='male',1,0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 16 columns):
# Age         1308 non-null float64
# Cabin       294 non-null object
# Embarked    1308 non-null object
# Fare        1308 non-null object
# Name        1308 non-null object
# Parch       1308 non-null float64
# Pclass      1308 non-null float64
# Sex         1308 non-null object
# SibSp       1308 non-null float64
# Survived    1308 non-null float64
# Ticket      1308 non-null object
# FareBin     1308 non-null category
# AgeState    1308 non-null object
# IsMother    1308 non-null float64
# Deck        1309 non-null object
# IsMale      1309 non-null int32
# dtypes: category(1), float64(6), int32(1), object(8)
# memory usage: 200.0+ KB

# %%
df=pd.get_dummies(df,columns=['Deck','Pclass','Embarked','FareBin','AgeState'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 31 columns):
# Age                 1308 non-null float64
# Cabin               294 non-null object
# Fare                1308 non-null object
# Name                1308 non-null object
# Parch               1308 non-null float64
# Sex                 1308 non-null object
# SibSp               1308 non-null float64
# Survived            1308 non-null float64
# Ticket              1308 non-null object
# IsMother            1308 non-null float64
# IsMale              1309 non-null int32
# Deck_A              1309 non-null uint8
# Deck_B              1309 non-null uint8
# Deck_C              1309 non-null uint8
# Deck_D              1309 non-null uint8
# Deck_E              1309 non-null uint8
# Deck_F              1309 non-null uint8
# Deck_G              1309 non-null uint8
# Deck_Z              1309 non-null uint8
# Pclass_1.0          1309 non-null uint8
# ...

# %%
df.drop(['Cabin','Fare','Age','Ticket','Parch','SibSp','Name'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 24 columns):
# Sex                 1308 non-null object
# Survived            1308 non-null float64
# IsMother            1308 non-null float64
# IsMale              1309 non-null int32
# Deck_A              1309 non-null uint8
# Deck_B              1309 non-null uint8
# Deck_C              1309 non-null uint8
# Deck_D              1309 non-null uint8
# Deck_E              1309 non-null uint8
# Deck_F              1309 non-null uint8
# Deck_G              1309 non-null uint8
# Deck_Z              1309 non-null uint8
# Pclass_1.0          1309 non-null uint8
# Pclass_2.0          1309 non-null uint8
# Pclass_3.0          1309 non-null uint8
# Embarked_C          1309 non-null uint8
# Embarked_Q          1309 non-null uint8
# Embarked_S          1309 non-null uint8
# FareBin_VeyLow      1309 non-null uint8
# FareBin_Low         1309 non-null uint8
# FareBin_High        1309 non-null uint8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 24 columns):
# Sex                 1308 non-null object
# Survived            1308 non-null float64
# IsMother            1308 non-null float64
# IsMale              1309 non-null int32
# Deck_A              1309 non-null uint8
# Deck_B              1309 non-null uint8
# Deck_C              1309 non-null uint8
# Deck_D              1309 non-null uint8
# Deck_E              1309 non-null uint8
# Deck_F              1309 non-null uint8
# Deck_G              1309 non-null uint8
# Deck_Z              1309 non-null uint8
# Pclass_1.0          1309 non-null uint8
# Pclass_2.0          1309 non-null uint8
# Pclass_3.0          1309 non-null uint8
# Embarked_C          1309 non-null uint8
# Embarked_Q          1309 non-null uint8
# Embarked_S          1309 non-null uint8
# FareBin_VeyLow      1309 non-null uint8
# FareBin_Low         1309 non-null uint8
# FareBin_High        1309 non-null uint8
# ...

# %%
columns=[column for column in df.columns if column !='Survived']
columns=['Survived']+columns
df=df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 24 columns):
# Survived            1308 non-null float64
# Sex                 1308 non-null object
# IsMother            1308 non-null float64
# IsMale              1309 non-null int32
# Deck_A              1309 non-null uint8
# Deck_B              1309 non-null uint8
# Deck_C              1309 non-null uint8
# Deck_D              1309 non-null uint8
# Deck_E              1309 non-null uint8
# Deck_F              1309 non-null uint8
# Deck_G              1309 non-null uint8
# Deck_Z              1309 non-null uint8
# Pclass_1.0          1309 non-null uint8
# Pclass_2.0          1309 non-null uint8
# Pclass_3.0          1309 non-null uint8
# Embarked_C          1309 non-null uint8
# Embarked_Q          1309 non-null uint8
# Embarked_S          1309 non-null uint8
# FareBin_VeyLow      1309 non-null uint8
# FareBin_Low         1309 non-null uint8
# FareBin_High        1309 non-null uint8
# ...

# %%
processed_data_path=os.path.join(os.path.pardir,'data','processed')
write_train_path=os.path.join('C:\Users\chbhakat\Desktop\DS\Kaggle\data\\raw\\train.csv')
write_test_path=os.path.join('C:\Users\chbhakat\Desktop\DS\Kaggle\data\\raw\\test.csv')

# %%
df.loc[df.Survived!=-888].to_csv(write_train_path)
columns=[column for column in df.columns if column!='Survived']
df.loc[df.Survived==-888,columns].to_csv(write_test_path)

# %%
model=XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eb322989fc05> in <module>()
# ----> 1 model=XGBClassifier()
#
# NameError: name 'XGBClassifier' is not defined
